# %% [markdown]
# **1. Основи роботи з умовними конструкціями (if-elif-else)**
#
# Створіть змінну `cooking_time = 5` (час варіння яєць у хвилинах)
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Яйце рідке" якщо cooking_time < 4
# - "Яйце всмятку" якщо 4 <= cooking_time < 7
# - "Яйце вкруту" якщо 7 <= cooking_time < 10
# - "Яйце переварене" якщо cooking_time >= 10

# %%
# Програма для оцінки ступеня звареності яйця
cooking_time = 5

if cooking_time >= 10:
    print("Яйце переварене")
elif cooking_time >= 7:
    print("Яйце вкруту")
elif cooking_time >= 4:
    print("Яйце всмятку")
else:
    print("Яйце рідке")
# Out:
# Яйце всмятку

# %% [markdown]
# ---
#
# **2. Перевірка оцінки**
#
# Створіть змінну `grade = 72`
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Відмінно" якщо grade >= 90
# - "Добре" якщо 75 <= grade < 90
# - "Задовільно" якщо 60 <= grade < 75
# - "Незадовільно" якщо grade < 60

# %%
# Програма для перевірки оцінки
grade = 72

if grade >= 90:
    print("Відмінно")
elif grade >= 75:
    print("Добре")
elif grade >= 60:
    print("Задовільно")
else:
    print("Незадовільно")
# Out:
# Задовільно

# %% [markdown]
# ---
#
# **3. Перевірка на наявність**
#
# Створіть список продуктів в холодильнику зі значеннями ["молоко", "яйця", "масло", "сир"] і запишіть його в змінну.
#
#
# Напишіть код, який перевіряє (кожен пункт оцінюється в 0.5 бала):
# - Чи є "яйця" в списку (виведіть "Яйця є в холодильнику" або "Яєць немає")
# - Чи є "хліб" в списку

# %%
# Програма для перевірки наявності продуктів у холодильнику (результат для продукту "яйця") 
food_list = ["молоко", "яйця", "масло", "сир"]

find_food = "яйця"
if find_food in food_list:
    print(f"{find_food} є в наявності!")
else:
    print("Такий продукт не знайдено!")
# Out:
# яйця є в наявності!

# %%
# Програма для перевірки наявності продуктів у холодильнику (результат для продукту "хліб") 
food_list = ["молоко", "яйця", "масло", "сир"]

find_food = "хліб"
if find_food in food_list:
    print(f"{find_food} є в наявності!")
else:
    print("Такий продукт не знайдено!")
# Out:
# Такий продукт не знайдено!
